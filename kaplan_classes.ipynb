# %% [markdown]
# <a href="https://colab.research.google.com/github/ducatyb/data/blob/main/kaplan_classes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !ls -l
# Out:
# total 40
# drwxr-xr-x 1 root root  4096 Aug 31 13:47  sample_data
# -rw-r--r-- 1 root root 34170 Sep  1 17:31 'timetable 30.08.22.xlsx'

# %%
import pandas as pd

# %%
df = pd.read_excel('timetable 30.08.22.xlsx', skiprows=4)
df
# Out:
#      Student ID      Student Forename Student Surname  \
# 0       6304526  Abdulaziz F KH GH SH      Aldhafeeri
# 1       6304901  Abdulkareem Rumian A        Alrumian
# 2       6303345     Abdullah Jamaan S        Binhajib
# 3       6303345     Abdullah Jamaan S        Binhajib
# 4       6300587            Abdullatif          Arslan
# ..          ...                   ...             ...
# 504     6304784                   Yun           Liang
# 505     6305217            Yusuf Eren           Celik
# 506     6301049                Zeynep            Tore
# 507     6302773           Zeynep Sude            Kaya
# 508     6302773           Zeynep Sude            Kaya
#
#                                    Class Name Room              Time
# 0                            F2F ELEMENTARY E    4   2:30pm - 5:45pm
# 1                              F2F ADVANCED 2   12  8:15am - 11:30am
# 2         F2F EL (B) SPEAKING & PRON (LI/INT)   10     1:05pm-2:20pm
# ...

# %%
from google.colab import data_table

# %%
data_table.enable_dataframe_formatter()

# %%
df_classes = df[['Class Name', 'Room', 'Time']].drop_duplicates()
df_classes
# Out:
#                                        Class Name         Room  \
# 0                                F2F ELEMENTARY E            4
# 1                                  F2F ADVANCED 2           12
# 2             F2F EL (B) SPEAKING & PRON (LI/INT)           10
# 3                              F2F INTERMEDIATE B            5
# 4                              F2F INTERMEDIATE F           10
# 5    F2F EL (B) SPEAKING AND VOCABULARY (ELEM/LI)            1
# 8                           F2F LOWER INT A (30+)          15a
# 9                              F2F INTERMEDIATE 2            1
# 11                       F2F LOWER INTERMEDIATE E           12
# 12                             F2F INTERMEDIATE A            4
# 13                       F2F LOWER INTERMEDIATE F           14
# 14                      F2F HIGHER INTERMEDIATE A            7
# 15                                F2F Beginners F          15a
# 16                      F2F HIGHER INTERMEDIATE C  London Room
# ...

# %%
df_classes[df['Time'].str.startswith('8:15')]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#                           Class Name         Room              Time
# 1                     F2F ADVANCED 2           12  8:15am - 11:30am
# 3                 F2F INTERMEDIATE B            5    8:15am-11:30am
# 8              F2F LOWER INT A (30+)          15a    8:15am-11:30am
# 9                 F2F INTERMEDIATE 2            1  8:15am - 11:30am
# 12                F2F INTERMEDIATE A            4    8:15am-11:30am
# 14         F2F HIGHER INTERMEDIATE A            7    8:15am-11:30am
# 16         F2F HIGHER INTERMEDIATE C  London Room    8:15am - 11:30
# 18          F2F LOWER INTERMEDIATE D            9    8:15am-11:30am
# 23                F2F INTERMEDIATE D          15b    8:15am-11:30am
# 24          F2F INTERMEDIATE C (30+)           14    8:15am-11:30am
# ...

# %%
df_classes[df['Time'].str.startswith('11:45')]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#                                    Class Name Room           Time
# 17     F2F EL (A) READING & SPEAKING (LI/INT)   10    11:45am-1pm
# 26        F2F EL (A) LISTENING_PRON  (INT/HI)  15a    11:45am-1pm
# 31   F2F EL (A) SPEAKING & WRITING  (ELEM/LI)   13    11:45am-1pm
# 44         F2F EL (A) 30+ MID SKILLS (INT/HI)    7    11:45am-1pm
# 53        F2F EL (A) SKILLS HIGH 2 (ADV/PROF)    2    11:45am-1pm
# 81   F2F EL (A) WRITING AND SPEAKING (INT/HI)   12    11:45am-1pm
# 84                      F2F EL (A) BUSINESS 2    9  11:45am - 1pm
# 87           F2F EL (A) SKILLS MID 4 (LI/INT)    1    11:45am-1pm
# 106           F2F EL (A) SKILLS HIGH (HI/ADV)    5    11:45am-1pm

# %%
df_classes[df['Time'].str.startswith('1:05')]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#                                        Class Name Room           Time
# 2             F2F EL (B) SPEAKING & PRON (LI/INT)   10  1:05pm-2:20pm
# 5    F2F EL (B) SPEAKING AND VOCABULARY (ELEM/LI)    1  1:05pm-2:20pm
# 19       F2F EL (B) LISTENING & SPEAKING (LI/INT)    6  1:05pm-2:20pm
# 35       F2F EL (B) WRITING & VOCABULARY (LI/INT)  15b  1:05pm-2:20pm
# 38                        F2F EL (B) IELTS (INT+)    8  1:05pm-2:20pm
# 61                 F2F EL (B) SKILLS 1 (BEG/ELEM)    7  1:05pm-2:20pm
# 73                 F2F EL (B) SKILLS MID (INT/HI)   14  1:05pm-2:20pm
# 177                     F2F EL (B) IELTS 2 (INT+)   11  1:05pm-2:20pm

# %%
df_classes[df['Time'].str.startswith('2:30')]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#                      Class Name Room             Time
# 0              F2F ELEMENTARY E    4  2:30pm - 5:45pm
# 4            F2F INTERMEDIATE F   10  2:30pm - 5:45pm
# 11     F2F LOWER INTERMEDIATE E   12  2:30pm - 5:45pm
# 13     F2F LOWER INTERMEDIATE F   14  2:30pm - 5:45pm
# 15              F2F Beginners F  15a  2:30pm - 5:45pm
# 20    F2F HIGHER INTERMEDIATE E    5  2:30pm - 5:45pm
# 21           F2F INTERMEDIATE E    1  2:30pm - 5:45pm
# 25           F2F INTERMEDIATE G   13  2:30pm - 5:45pm
# 27    F2F HIGHER INTERMEDIATE G    2  2:30pm - 5:45pm
# 72   F2F ELEMENTARY/LOWER INT E    8  2:30pm - 5:45pm
# 124      F2F ELEMENTARY F (30+)  15b  2:30pm - 5:45pm
# 140                 F2F IELTS F   11  2:30pm - 5:45pm
# 164   F2F HIGHER INTERMEDIATE F    7  2:30pm - 5:45pm

# %%
df_classes[df['Class Name'].str.contains('IELTS')]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#                     Class Name Room             Time
# 38     F2F EL (B) IELTS (INT+)    8    1:05pm-2:20pm
# 70                 F2F IELTS D    8   8:15am-11:30am
# 140                F2F IELTS F   11  2:30pm - 5:45pm
# 177  F2F EL (B) IELTS 2 (INT+)   11    1:05pm-2:20pm
